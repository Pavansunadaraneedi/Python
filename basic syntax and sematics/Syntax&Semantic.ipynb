# %% [markdown]
# Syntax & Semantic
#
# Syntax: Syntax refers to the set of rules that difines the combination of symbols thta are considered to be correctly structured program in a language. In simple terms, syntax is about the correct arrangement of words and symbols ina code.
#
# Semantic: Semantic refers to the meaning or the interpretation of the symbols, charcters, and commands in a language. It is about what the code is supposed to do when it runs.

# %%
## Basic Syntax rule in Python
## Case sensitivity - Python is Case sensitive

name = "Pavan"
Name = "Sundaraneedi"

print(name)
print(Name)
# Out:
# Pavan
# Sundaraneedi

# %% [markdown]
# **Indentation**
# Indentation in Python is used to define the structure and hierarchy of the code. Unlike many other programming languages that use braces{} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be indented at the same level.

# %%
## Indentation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.

age=32
if age>30:
    print(age)

print(age)
# Out:
# 32
# 32

# %%
##This is a single line comment

print("Hello world")
# Out:
# Hello world

# %%
## Line continuation 
## Use a backslash (\) to continue a syayement to the next line

total = 1+2+3+4+5+6+\
7+8+9

print(total)
# Out:
# 45

# %%
## Multiple statement in a single line

x=5;y=10;z=x+y
print(x+y)
# Out:
# 15

# %%
## Understand Semmantic in Python
# Variable assignment 

age=23 #int
name="Pavan" #str

type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type INference
variable=10
print(type(variable))
variable="Pavan"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
    print(age)
# Out:
# 32

# %%
## Name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
## code example of indentation 

    print("correct indentation")
    if False:
        print("This wont print")
    print("this will print")
print("outside the block")
# Out:
# correct indentation
# this will print
# outside the block
