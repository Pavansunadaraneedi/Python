# %% [markdown]
# **Inheritance In Python**
#
# Inheritance in Python is an Object-Oriented Programming (OOP) concept where one class (child class) acquires the properties and behaviors (variables and methods) of another class (parent class).
# It helps you reuse code, avoid duplication, and build hierarchical relationships between classes.

# %%
## Inheritance (Single inheritance)
## Parent class
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype}")

# %%
car1=Car(4,5,"petrol")
print(car1.drive())
# Out:
# The person will drive the petrol
# None

# %% [markdown]
# **Super()** : The super keyword in Python is used inside a child class to call methods or constructors of its parent class.
# It helps you access and reuse parent class behavior without writing the parent class name directly.

# %%
class Tesla(Car):
    def __init__(self, windows, doors, enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving = is_selfdriving

    def selfdriving(self):
        print(f"Tesla Supports self driving : {self.is_selfdriving}")

# %%
tesla1=Tesla(4,5,"electric", True)
tesla1.selfdriving()
# Out:
# Tesla Supports self driving : True

# %%
tesla1.drive()
# Out:
# The person will drive the electric

# %%
## Multiple Inheritance
## When a class inherits from more than one base class

class Animal:
    def __init__(self, name):
        self.name=name
    
    def speak(self):
        print("Subclass must implement in this method")

## Base class 2
class Pet:
    def __init__(self, owner):
        self.owner=owner

## Derived class
class Dog(Animal, Pet):
     def __init__(self,name,owner):
         Animal.__init__(self,name)
         Pet.__init__(self,owner)
    
     def speak(self):
         return f"{self.name} say woof"

## Create an object 
dog=Dog("Buddy","Krish")
print(dog.speak())
print(f"Owner : {dog.owner}")
# Out:
# Buddy say woof
# Owner : Krish
