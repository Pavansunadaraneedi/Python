# %% [markdown]
# ## Lambda Function in Python
#
# A lambda function is a small anonymous function defined using lambda keyword.They can have any numbe of arguments but only one expression. They are commonly used for short operation or as argument to higher-order functions

# %%
## Syntax
lambda arguments: expression
# Out:
# <function __main__.<lambda>(arguments)>

# %%
def addition(a,b):
    return a+b

# %%
addition(2,3)
# Out:
# 5

# %%
addition=lambda a,b:a+b
type(addition)
print(addition(5,6))
# Out:
# 11

# %%
def even(num):
    if num%2==0:
        return True
even(24)
# Out:
# True

# %%
even1=lambda num:num%2==0
even1(12)
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z
addition(12,13,14)
# Out:
# 39

# %%
addition1=lambda x,y,z:x+y+z
addition(12,13,14)
# Out:
# 39

# %%
## map() - It applies a function to all items in a list 
numbers=[1,2,3,4,5,6]
def square(numbers):
    return numbers**2
square(2)
# Out:
# 4

# %%
list(map(lambda x:x**2,numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# ## The map() Function in Python
#
# The map() function applies given function to all items in an input list (or any other iterable) and returns a map object(an iteration).This is particular useful for transformation data in a list comprehesively

# %%
def square(x):
    return x*x
square(10)
# Out:
# 100

# %%
numbers = [1,2,3,4,5,6,7,8]

list(map(square,numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
## Lambda Function with map()
numbers = [1,2,3,4,5,6,7,8]
list(map(lambda x:x*x,numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
## Can we map multiple iterables

numbers1=[1,2,3]
numbers2=[4,5,6]

added_numbers=list(map(lambda x,y:x+y, numbers1,numbers2))
print(added_numbers)
# Out:
# [5, 7, 9]

# %%
## map() to conver a list of strings to integers
## Use map to conver strings to integers

str_numbers =['1','2','3','4','5']
int_numbers =list(map(int, str_numbers))

print(int_numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
words=['apple','banana','cherry']
upper_words=list(map(str.upper,words))
print(upper_words)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
def get_name(person):
    return person['name']

people=[
    {'name':'Pavan','age':23},
    {'name':'Ammu','age':22}
]
list(map(get_name,people))
# Out:
# ['Pavan', 'Ammu']

# %% [markdown]
# # Conclusion:
#
# The map() function is a powerful tool for applying tranformations to iterable data structure. It can be used with regular function, lambda functions, and even multiple iterables, providing a versatile approach to data processing in python. by understanding and utilitzing map(), you can write more efficent and readale code.
